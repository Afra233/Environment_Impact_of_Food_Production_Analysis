# %% [markdown]
# # **Environmental Impact of Food Production: Analysis Overview**
#
# ## **Business Understanding**
# The environmental repercussions of food production are a major global concern, influencing climate change, water scarcity, and biodiversity loss. With the rising demand for food driven by population growth and economic progress, the key challenge lies in producing food in a manner that sustains both the environment and the population. This project aims to assess the environmental footprint of various food products and uncover opportunities to mitigate their impact.
#
# ## **Objectives/Goals**
# - Evaluate the environmental impact of food production across multiple stages (e.g., land usage, water consumption, carbon emissions).
# - Identify food products that are most and least sustainable, based on environmental criteria.
# - Provide actionable insights to assist policymakers, businesses, and consumers in making informed, eco-friendly decisions.
# - Suggest strategies for reducing the environmental impact associated with food production.
#
# ## **Problem Statement**
# Food production plays a significant role in contributing to greenhouse gas emissions, water pollution, and deforestation. The environmental toll varies by food type and production method. Without a comprehensive analysis, key stakeholders lack the insights necessary to make more sustainable food choices. This project seeks to quantify and analyze the environmental impact of food production, providing a foundation for more sustainable practices.
#
# ## **Stakeholders**
# - **Government and policymakers**: To craft regulations and policies promoting sustainable food production.
# - **Agricultural and food industries**: To implement environmentally conscious farming and production techniques.
# - **Consumers**: To make more informed decisions about sustainable food consumption.
# - **Environmental organizations**: To advocate for food systems that prioritize sustainability.
# - **Researchers and data scientists**: To further explore and study the environmental impacts of food production.
#
# ## **Key Data Points (Features)**
# - Land use change (Kg CO₂-equivalents per kg product)
# - Animal feed (Kg CO₂-equivalents per kg product)
# - Farm emissions (Kg CO₂-equivalents per kg product)
# - Processing emissions (Kg CO₂-equivalents per kg product)
# - Transport emissions (Kg CO₂-equivalents per kg product)
# - Packaging emissions (Kg CO₂-equivalents per kg product)
# - Retail emissions (Kg CO₂-equivalents per kg product)
# - Water usage per kg of food
# - Impact on eutrophication (water pollution due to excess nutrients)
# - Biodiversity impact
#
# ## **Hypotheses**
# - Animal-based food production tends to have a higher environmental footprint than plant-based food.
# - Transport emissions are a significant contributor to the total carbon footprint of food production.
# - Processed foods generally have a higher carbon footprint due to the added energy required for processing.
# - Locally produced food has a lower environmental impact due to reduced transport emissions.
# - Higher land use change values are associated with increased biodiversity loss.
# - Water-intensive crops exacerbate water scarcity issues.
# - Sustainable farming methods (e.g., organic, regenerative agriculture) lead to a lower environmental impact.
#
# ## **Analytical Questions**
# 1. Which food products generate the highest and lowest carbon emissions?
# 2. How does the environmental impact of animal-based foods compare with plant-based alternatives?
# 3. What is the relationship between land use change and biodiversity loss?
# 4. Which stage of food production (farming, processing, transportation, packaging, retail) contributes the most to carbon emissions?
# 5. How does the distance food travels during transportation affect its overall emissions?
# 6. Which foods are most responsible for eutrophication (water pollution)?
# 7. What are the most environmentally sustainable food options based on key impact metrics?

# %%
# !pip install matplotlib seaborn
# Out:
# ...
#   Using cached matplotlib-3.10.1-cp313-cp313-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
# Using cached matplotlib-3.10.1-cp313-cp313-win_amd64.whl (8.1 MB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...

# %% [markdown]
# ### **1. Data Loading**

# %%
# Importing necessary libraries
# Data manipulation and analysis
import pandas as pd
import numpy as np

# Data visualization
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.impute import SimpleImputer

import warnings
warnings.filterwarnings("ignore")

# %%
# Load the dataset
data = pd.read_csv("C:\\Users\\LENOVO\\Desktop\\Azubi Africa TMP\\Environment_Impact_of_Food_Production_Analysis\\Notebook\\Data\\Food_Production.csv")
data
# Out:
#            Food product  Land use change  Animal Feed  Farm  Processing  \
# 0   Wheat & Rye (Bread)              0.1          0.0   0.8         0.2
# 1          Maize (Meal)              0.3          0.0   0.5         0.1
# 2         Barley (Beer)              0.0          0.0   0.2         0.1
# 3               Oatmeal              0.0          0.0   1.4         0.0
# 4                  Rice              0.0          0.0   3.6         0.1
# 5              Potatoes              0.0          0.0   0.2         0.0
# 6               Cassava              0.6          0.0   0.2         0.0
# 7            Cane Sugar              1.2          0.0   0.5         0.0
# 8            Beet Sugar              0.0          0.0   0.5         0.2
# 9          Other Pulses              0.0          0.0   1.1         0.0
# 10                 Peas              0.0          0.0   0.7         0.0
# 11                 Nuts             -2.1          0.0   2.1         0.0
# ...

# %%
# Display basic info about the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 23 columns):
#  #   Column                                                                   Non-Null Count  Dtype
# ---  ------                                                                   --------------  -----
#  0   Food product                                                             43 non-null     object
#  1   Land use change                                                          43 non-null     float64
#  2   Animal Feed                                                              43 non-null     float64
#  3   Farm                                                                     43 non-null     float64
#  4   Processing                                                               43 non-null     float64
#  5   Transport                                                                43 non-null     float64
# ...

# %%
# Check for missing values
print("Missing values per column:")
print(data.isnull().sum())
# Out:
# Missing values per column:
# Food product                                                                0
# Land use change                                                             0
# Animal Feed                                                                 0
# Farm                                                                        0
# Processing                                                                  0
# Transport                                                                   0
# Packging                                                                    0
# Retail                                                                      0
# Total_emissions                                                             0
# Eutrophying emissions per 1000kcal (gPO₄eq per 1000kcal)                   10
# Eutrophying emissions per kilogram (gPO₄eq per kilogram)                    5
# Eutrophying emissions per 100g protein (gPO₄eq per 100 grams protein)      16
# ...

# %%
# filling missing values using the mean
numeric_columns = data.select_dtypes(include=[np.number]).columns
imputer = SimpleImputer(strategy='mean')
data[numeric_columns] = imputer.fit_transform(data[numeric_columns])

# %%
# Check for any remaining missing values
print(data.isnull().sum())
# Out:
# Food product                                                               0
# Land use change                                                            0
# Animal Feed                                                                0
# Farm                                                                       0
# Processing                                                                 0
# Transport                                                                  0
# Packging                                                                   0
# Retail                                                                     0
# Total_emissions                                                            0
# Eutrophying emissions per 1000kcal (gPO₄eq per 1000kcal)                   0
# Eutrophying emissions per kilogram (gPO₄eq per kilogram)                   0
# Eutrophying emissions per 100g protein (gPO₄eq per 100 grams protein)      0
# ...

# %%
# Verify the shape of the dataframe
print(f"Shape of the dataframe: {data.shape}")
# Out:
# Shape of the dataframe: (43, 23)

# %%
#Summary Statistics
data.describe()
# Out:
#        Land use change  Animal Feed       Farm  Processing  Transport  \
# count        43.000000    43.000000  43.000000   43.000000  43.000000
# mean          1.260465     0.453488   3.469767    0.253488   0.195349
# std           3.357730     0.919200   7.083264    0.372475   0.158795
# min          -2.100000     0.000000   0.100000    0.000000   0.000000
# 25%           0.000000     0.000000   0.350000    0.000000   0.100000
# 50%           0.200000     0.000000   0.800000    0.100000   0.100000
# 75%           0.800000     0.000000   2.200000    0.300000   0.200000
# max          16.300000     2.900000  39.400000    1.300000   0.800000
#
#         Packging     Retail  Total_emissions  \
# count  43.000000  43.000000        43.000000
# mean    0.269767   0.069767         5.972093
# std     0.342633   0.110270        10.501753
# min     0.000000   0.000000         0.200000
# 25%     0.100000   0.000000         0.850000
# 50%     0.100000   0.000000         1.600000
# ...

# %%
# Get the list of all column names in the DataFrame
columns = data.columns
 
# Print details of unique values for each column in the DataFrame
for column in columns:
    print(f'{column}')  
    print(f'There are {data[column].unique().size} unique values')  
    print(f'{data[column].unique()}')  
    print('_' * 80)
# Out:
# Food product
# There are 43 unique values
# ['Wheat & Rye (Bread)' 'Maize (Meal)' 'Barley (Beer)' 'Oatmeal' 'Rice'
#  'Potatoes' 'Cassava' 'Cane Sugar' 'Beet Sugar' 'Other Pulses' 'Peas'
#  'Nuts' 'Groundnuts' 'Soymilk' 'Tofu' 'Soybean Oil' 'Palm Oil'
#  'Sunflower Oil' 'Rapeseed Oil' 'Olive Oil' 'Tomatoes' 'Onions & Leeks'
#  'Root Vegetables' 'Brassicas' 'Other Vegetables' 'Citrus Fruit' 'Bananas'
#  'Apples' 'Berries & Grapes' 'Wine' 'Other Fruit' 'Coffee'
#  'Dark Chocolate' 'Beef (beef herd)' 'Beef (dairy herd)' 'Lamb & Mutton'
#  'Pig Meat' 'Poultry Meat' 'Milk' 'Cheese' 'Eggs' 'Fish (farmed)'
#  'Shrimps (farmed)']
# ________________________________________________________________________________
# Land use change
# There are 21 unique values
# [ 0.1  0.3  0.   0.6  1.2 -2.1  0.4  0.2  1.   3.1 -0.4 -0.1  3.7 14.3
#  16.3  0.9  0.5  1.5  2.5  4.5  0.7]
# ________________________________________________________________________________
# Animal Feed
# There are 10 unique values
# ...

# %% [markdown]
# ### **2. Exploratory Data Analysis**

# %%
# Set up the plotting style
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette("viridis")
plt.rcParams.update({'font.size': 12})

# %%
# Function to create and save figures
def save_figure(fig, filename):
    fig.tight_layout()
    plt.savefig(filename, dpi=300, bbox_inches='tight')
    plt.close(fig)

# %%
# 1. Highest and lowest carbon emissions
    # Sort by Total_emissions
sorted = data.sort_values('Total_emissions', ascending=False).dropna(subset=['Total_emissions'])
    
    # Create figure
plt.figure(figsize=(14, 8))
    
    # Create a color palette
bars = plt.bar(sorted['Food product'], sorted['Total_emissions'])
    
    # Highlight the top 5 and bottom 5
for i in range(5):
        bars[i].set_color('darkred')
        bars[-(i+1)].set_color('darkgreen')
    
    # Add labels and title
plt.xlabel('Food Product')
plt.ylabel('Total Emissions (kgCO₂eq per kg)')
plt.title('Total Carbon Emissions by Food Product', fontsize=16, fontweight='bold')
    
    # Rotate x-axis labels for better readability
plt.xticks(rotation=90)
    
    # Add gridlines for easier reading
plt.grid(axis='y', linestyle='--', alpha=0.7)
    
plt.tight_layout()
plt.show()

# %% [markdown]
# The highest carbon emitters are:
# - Beef (beef herd): 59.6 kgCO₂eq per kg
# - Lamb & Mutton: 24.5 kgCO₂eq per kg
# - Beef (dairy herd): 21.1 kgCO₂eq per kg
# - Cheese: 21.2 kgCO₂eq per kg
# - Dark Chocolate: 18.7 kgCO₂eq per kg
#
# The lowest carbon emitters are:
# - Nuts: 0.2 kgCO₂eq per kg (likely due to carbon sequestration from nut trees)
# - Citrus Fruit: 0.3 kgCO₂eq per kg
# - Potatoes: 0.3 kgCO₂eq per kg
# - Onions & Leeks: 0.3 kgCO₂eq per kg
# - Apples: 0.3 kgCO₂eq per kg

# %%
# 2. Animal-based vs plant-based comparison
    # Define animal-based and plant-based food categories
animal_based = ['Beef (beef herd)', 'Beef (dairy herd)', 'Lamb & Mutton', 'Pig Meat', 
                   'Poultry Meat', 'Milk', 'Cheese', 'Eggs', 'Fish (farmed)', 'Shrimps (farmed)']
    
plant_based = ['Wheat & Rye (Bread)', 'Maize (Meal)', 'Barley (Beer)', 'Oatmeal', 'Rice', 
                  'Potatoes', 'Cassava', 'Cane Sugar', 'Beet Sugar', 'Other Pulses', 'Peas', 
                  'Nuts', 'Groundnuts', 'Soymilk', 'Tofu', 'Soybean Oil', 'Palm Oil', 
                  'Sunflower Oil', 'Rapeseed Oil', 'Olive Oil', 'Tomatoes', 'Onions & Leeks', 
                  'Root Vegetables', 'Brassicas', 'Other Vegetables', 'Citrus Fruit', 'Bananas', 
                  'Apples', 'Berries & Grapes', 'Wine', 'Other Fruit']
    
    # Create a new column for food category
data['Food Category'] = 'Other'
data.loc[data['Food product'].isin(animal_based), 'Food Category'] = 'Animal-based'
data.loc[data['Food product'].isin(plant_based), 'Food Category'] = 'Plant-based'
    
    # Choose one metric at a time for simplicity
    # For carbon emissions:
plt.figure(figsize=(10, 6))
    
    # Group by food category and calculate mean
category_avg = data.groupby('Food Category')['Total_emissions'].mean().reindex(['Plant-based', 'Animal-based'])
    
    # Create bar plot
bar_colors = ['#2ecc71', '#e74c3c']  # Green for plant, red for animal
bars = plt.bar(category_avg.index, category_avg.values, color=bar_colors)
    
    # Add value labels on top of each bar
for bar in bars:
        height = bar.get_height()
        plt.annotate(f'{height:.1f}',
                   xy=(bar.get_x() + bar.get_width() / 2, height),
                   xytext=(0, 3),  # 3 points vertical offset
                   textcoords="offset points",
                   ha='center', va='bottom', fontweight='bold')
    
    # Add labels and title
plt.title('Carbon Emissions: Animal-based vs Plant-based Foods', fontsize=14, fontweight='bold')
plt.ylabel('Average Emissions (kgCO₂eq per kg)')
    
    # Add ratio text
ratio = category_avg['Animal-based'] / category_avg['Plant-based']
plt.annotate(f'Animal:Plant Ratio = {ratio:.1f}x',
               xy=(0.5, 0.9),
               xycoords='axes fraction',
               ha='center',
               bbox=dict(boxstyle="round,pad=0.3", fc='#f9f9f9', ec="gray", alpha=0.8))
    
plt.tight_layout()
plt.show()

# %% [markdown]
# Animal-based foods have significantly higher environmental impacts than plant-based foods across all metrics:
# - Carbon emissions: Animal products emit about 5-6 times more carbon than plant products
# - Land use: Animal products require 4-5 times more land per kg
# - Water usage: Animal products use approximately 2-3 times more water
# - Eutrophication: Animal products cause about 3-4 times more water pollution

# %%
# Extract and sort the land use change data
land_use_change = data[['Food product', 'Land use change']]
land_use_change = land_use_change.sort_values('Land use change', ascending=False)
land_use_change = land_use_change.dropna()

# Create visualization
plt.figure(figsize=(12, 10))
bars = sns.barplot(x='Land use change', y='Food product', data=land_use_change, palette='RdYlGn_r')

# Highlight negative values (potential biodiversity benefits) in green
for i, bar in enumerate(bars.patches):
    if bar.get_width() < 0:
        bar.set_color('green')

plt.title('Land Use Change Impact by Food Product (kgCO₂eq per kg product)', fontsize=14)
plt.xlabel('Land Use Change Emissions (kgCO₂eq)', fontsize=12)
plt.ylabel('Food Product', fontsize=12)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()

# Add a vertical line at x=0 to highlight positive vs negative impact
plt.axvline(x=0, color='black', linestyle='-', alpha=0.5)

# Save the figure
plt.show()

# %% [markdown]
# Foods with the highest land use change emissions (and thus likely negative biodiversity impact) are:
# - Dark Chocolate: 14.3 kgCO₂eq per kg
# - Beef (beef herd): 16.3 kgCO₂eq per kg
# - Coffee: 3.7 kgCO₂eq per kg
# - Palm Oil: 3.1 kgCO₂eq per kg
# - Soybean Oil: 3.1 kgCO₂eq per kg
#
# Some foods show negative land use change values, potentially indicating biodiversity preservation:
# - Nuts: -2.1 kgCO₂eq per kg (likely from long-term tree cultivation)
# - Olive Oil: -0.4 kgCO₂eq per kg
# - Citrus Fruit: -0.1 kgCO₂eq per kg
# - Wine: -0.1 kgCO₂eq per kg

# %%
# 4. Which stage of food production contributes the most to carbon emissions?
    # Select the production stage columns
stages = ['Land use change', 'Animal Feed', 'Farm', 'Processing', 
              'Transport', 'Packging', 'Retail']
    
    # Calculate the average emissions by stage across all products
stage_means = data[stages].mean().sort_values(ascending=False)
    
    # Create a figure
fig, ax = plt.subplots(figsize=(14, 8))
    
    # Create a bar chart
bars = ax.bar(stage_means.index, stage_means.values, color=sns.color_palette("viridis", len(stages)))
    
    # Add value labels
for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.2f}',
                   xy=(bar.get_x() + bar.get_width() / 2, height),
                   xytext=(0, 3),  # 3 points vertical offset
                   textcoords="offset points",
                   ha='center', va='bottom', fontweight='bold')
    
    # Add labels and title
ax.set_xlabel('Production Stage')
ax.set_ylabel('Average Emissions (kgCO₂eq per kg)')
ax.set_title('Average Carbon Emissions by Food Production Stage', fontsize=16, fontweight='bold')
    
    # Calculate and display the percentage of total emissions
total = stage_means.sum()
percentages = [(value / total) * 100 for value in stage_means.values]
    
for i, (bar, percentage) in enumerate(zip(bars, percentages)):
        ax.annotate(f'{percentage:.1f}%',
                   xy=(bar.get_x() + bar.get_width() / 2, bar.get_height() / 2),
                   ha='center', va='center', color='white', fontweight='bold')
    
    # Add a grid for easier reading
ax.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %% [markdown]
# The farming stage contributes the most to emissions (58.1%), followed by:
# - Land use change (21.1%)
# - Animal feed (7.6%)
# - Packaging (4.5%)
# - Processing (4.2%)
# - Transport (3.3%)
# - Retail (1.2%)

# %%
# 5. How does the distance food travels during transportation affect its overall emissions?
    # Create a new column for the percentage of emissions from transport
data['Transport_percentage'] = (data['Transport'] / data['Total_emissions']) * 100
    
    # Sort by transport percentage
sorted = data.sort_values('Transport_percentage', ascending=False).head(20)
    
    # Create figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 10))
    
    # Plot 1: Transport emissions vs. total emissions
scatter = ax1.scatter(data['Transport'], data['Total_emissions'], 
                         alpha=0.7, s=100, c=data['Transport'] / data['Total_emissions'], 
                         cmap='viridis')
    
    # Add a color bar
cbar = plt.colorbar(scatter, ax=ax1)
cbar.set_label('Transport Emissions / Total Emissions')
    
    # Add labels and title
ax1.set_xlabel('Transport Emissions (kgCO₂eq per kg)')
ax1.set_ylabel('Total Emissions (kgCO₂eq per kg)')
ax1.set_title('Transport Emissions vs. Total Emissions', fontsize=14, fontweight='bold')
    
    # Add annotations for key products
for i, row in data.iterrows():
        if row['Transport'] > 0.4 or row['Transport'] / row['Total_emissions'] > 0.2:
            ax1.annotate(row['Food product'], 
                       xy=(row['Transport'], row['Total_emissions']),
                       xytext=(5, 0), textcoords='offset points')
    
    # Plot 2: Products with highest transport percentage
colors = sns.color_palette("viridis", len(sorted))
bars = ax2.barh(sorted['Food product'], sorted['Transport_percentage'], color=colors)
    
    # Add labels and title
ax2.set_xlabel('Transport as Percentage of Total Emissions (%)')
ax2.set_title('Foods with Highest Transport Emissions (Relative)', fontsize=14, fontweight='bold')
    
    # Add value labels
for bar in bars:
        width = bar.get_width()
        ax2.annotate(f'{width:.1f}%',
                    xy=(width, bar.get_y() + bar.get_height()/2),
                    xytext=(5, 0),  # 3 points horizontal offset
                    textcoords="offset points",
                    ha='left', va='center')
    
    # Add gridlines
ax2.grid(axis='x', linestyle='--', alpha=0.7)

plt.show()

# %% [markdown]
# Transportation contributes relatively little to most foods' overall emissions (average ~7%). Foods where transportation makes up a higher percentage of emissions include:
#
# - Wine: Transport accounts for 7.1% of emissions
# - Bananas: Transport accounts for 37.5% of emissions
# - Berries & Grapes: Transport accounts for 18.2% of emissions

# %%
# 6. Which foods are most responsible for eutrophication (water pollution)?
    # Select foods with eutrophication data and sort
eutro = data.dropna(subset=['Eutrophying emissions per kilogram (gPO₄eq per kilogram)'])
sorted = eutro.sort_values('Eutrophying emissions per kilogram (gPO₄eq per kilogram)', 
                                     ascending=False).head(15)
    
    # Create figure
fig, ax = plt.subplots(figsize=(16, 10))
    
    # Plot with a colormap
bars = ax.bar(sorted['Food product'], 
                 sorted['Eutrophying emissions per kilogram (gPO₄eq per kilogram)'],
                 color=sns.color_palette("YlOrRd", len(sorted)))
    
    # Add labels and title
ax.set_xlabel('Food Product')
ax.set_ylabel('Eutrophying Emissions (gPO₄eq per kg)')
ax.set_title('Top 15 Foods Contributing to Eutrophication', fontsize=16, fontweight='bold')
    
    # Rotate x-axis labels
plt.xticks(rotation=45, ha='right')
    
    # Add value labels
for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.1f}',
                   xy=(bar.get_x() + bar.get_width() / 2, height),
                   xytext=(0, 3),
                   textcoords="offset points",
                   ha='center', va='bottom')
    
    # Add explanation text
ax.text(0.05, 0.95, 'Higher values indicate greater potential for water pollution\nthrough excess nutrients (e.g., phosphorus, nitrogen)',
            transform=ax.transAxes, fontsize=12, verticalalignment='top',
            bbox=dict(boxstyle="round,pad=0.3", fc='#f9f9f9', ec="gray", alpha=0.8))
    
    # Add gridlines
ax.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %% [markdown]
# The top eutrophication contributors are:
# - Coffee: 110.5 gPO₄eq per kg
# - Fish (farmed): 235.1 gPO₄eq per kg
# - Beef (dairy herd): 365.3 gPO₄eq per kg
# - Beef (beef herd): 301.4 gPO₄eq per kg

# %%
# 7. What are the most environmentally sustainable food options based on key impact metrics?
    # Select key metrics for sustainability ranking
metrics = ['Total_emissions', 
               'Land use per kilogram (m² per kilogram)',
               'Freshwater withdrawals per kilogram (liters per kilogram)',
               'Eutrophying emissions per kilogram (gPO₄eq per kilogram)']
    
    # Select data with all metrics available
complete = data.dropna(subset=metrics)
    
    # Normalize each metric (min-max scaling)
normalized = complete.copy()
for metric in metrics:
        min_val = complete[metric].min()
        max_val = complete[metric].max()
        normalized[f'{metric}_normalized'] = (complete[metric] - min_val) / (max_val - min_val)
    
    # Calculate a combined sustainability score (lower is better)
normalized_metrics = [f'{metric}_normalized' for metric in metrics]
normalized['sustainability_score'] = normalized[normalized_metrics].mean(axis=1)
    
    # Sort by sustainability score (lower is better)
sorted = normalized.sort_values('sustainability_score')
    
    # Select top 15 and bottom 5 for visualization
top_sustainable = sorted.head(15)
least_sustainable = sorted.tail(5)
    
    # Combine them for the plot
plot = pd.concat([top_sustainable, least_sustainable])
    
    # Create figure
fig, ax = plt.subplots(figsize=(16, 12))
    
    # Create color gradient - green for sustainable, red for unsustainable
colors = []
for score in plot['sustainability_score']:
        if score < 0.2:  # Most sustainable
            colors.append('#1e8449')  # Dark green
        elif score < 0.4:
            colors.append('#2ecc71')  # Green
        elif score < 0.6:
            colors.append('#f4d03f')  # Yellow
        elif score < 0.8:
            colors.append('#e67e22')  # Orange
        else:
            colors.append('#c0392b')  # Red
    
    # Create horizontal bar chart
bars = ax.barh(plot['Food product'], plot['sustainability_score'], color=colors)
    
    # Add labels and title
ax.set_xlabel('Environmental Impact Score (Lower is Better)')
ax.set_title('Most and Least Environmentally Sustainable Foods\n(Based on Combined Impact Metrics)', 
                fontsize=16, fontweight='bold')
    
    # Add a separator line between top and bottom groups
ax.axhline(y=14.5, color='black', linestyle='--', alpha=0.5)
    
    # Add annotations
ax.text(0.05, 0.98, 'Least Sustainable Options',
            transform=ax.transAxes, fontsize=14, fontweight='bold',
            verticalalignment='top', color='#1e8449',
            bbox=dict(boxstyle="round,pad=0.3", fc='white', ec="#1e8449", alpha=0.9))
    
ax.text(0.05, 0.12, 'Most Sustainable Options',
            transform=ax.transAxes, fontsize=14, fontweight='bold',
            verticalalignment='top', color='#c0392b',
            bbox=dict(boxstyle="round,pad=0.3", fc='white', ec="#c0392b", alpha=0.9))
    
    # Add explanation text
ax.text(0.5, 0.05, 'Score combines emissions, land use, water use, and eutrophication metrics',
            transform=ax.transAxes, fontsize=12, ha='center',
            bbox=dict(boxstyle="round,pad=0.3", fc='#f9f9f9', ec="gray", alpha=0.8))
    
    # Add value labels
for bar in bars:
        width = bar.get_width()
        ax.annotate(f'{width:.2f}',
                   xy=(width, bar.get_y() + bar.get_height()/2),
                   xytext=(5, 0),
                   textcoords="offset points",
                   ha='left', va='center')
    
    # Add gridlines
ax.grid(axis='x', linestyle='--', alpha=0.7)

plt.show()

# %% [markdown]
# Based on combined metrics (emissions, land use, water use, and eutrophication):
# 1. The most sustainable options include:
# - Potatoes
# - Onions & Leeks
# - Root Vegetables
# - Apples
# - Citrus Fruit
# - Nuts (despite higher water usage, they have carbon sequestration benefits)
#
# 2. The least sustainable options include:
# - Beef (beef herd)
# - Lamb & Mutton
# - Beef (dairy herd)
# - Fish (farmed)
# - Cheese
