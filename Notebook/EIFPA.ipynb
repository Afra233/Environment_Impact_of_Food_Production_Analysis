# %% [markdown]
# # **Environmental Impact of Food Production: Analysis Overview**
#
# ## **Business Understanding**
# The environmental repercussions of food production are a major global concern, influencing climate change, water scarcity, and biodiversity loss. With the rising demand for food driven by population growth and economic progress, the key challenge lies in producing food in a manner that sustains both the environment and the population. This project aims to assess the environmental footprint of various food products and uncover opportunities to mitigate their impact.
#
# ## **Objectives/Goals**
# - Evaluate the environmental impact of food production across multiple stages (e.g., land usage, water consumption, carbon emissions).
# - Identify food products that are most and least sustainable, based on environmental criteria.
# - Provide actionable insights to assist policymakers, businesses, and consumers in making informed, eco-friendly decisions.
# - Suggest strategies for reducing the environmental impact associated with food production.
#
# ## **Problem Statement**
# Food production plays a significant role in contributing to greenhouse gas emissions, water pollution, and deforestation. The environmental toll varies by food type and production method. Without a comprehensive analysis, key stakeholders lack the insights necessary to make more sustainable food choices. This project seeks to quantify and analyze the environmental impact of food production, providing a foundation for more sustainable practices.
#
# ## **Stakeholders**
# - **Government and policymakers**: To craft regulations and policies promoting sustainable food production.
# - **Agricultural and food industries**: To implement environmentally conscious farming and production techniques.
# - **Consumers**: To make more informed decisions about sustainable food consumption.
# - **Environmental organizations**: To advocate for food systems that prioritize sustainability.
# - **Researchers and data scientists**: To further explore and study the environmental impacts of food production.
#
# ## **Key Data Points (Features)**
# - Land use change (Kg CO₂-equivalents per kg product)
# - Animal feed (Kg CO₂-equivalents per kg product)
# - Farm emissions (Kg CO₂-equivalents per kg product)
# - Processing emissions (Kg CO₂-equivalents per kg product)
# - Transport emissions (Kg CO₂-equivalents per kg product)
# - Packaging emissions (Kg CO₂-equivalents per kg product)
# - Retail emissions (Kg CO₂-equivalents per kg product)
# - Water usage per kg of food
# - Impact on eutrophication (water pollution due to excess nutrients)
# - Biodiversity impact
#
# ## **Hypotheses**
# - Animal-based food production tends to have a higher environmental footprint than plant-based food.
# - Transport emissions are a significant contributor to the total carbon footprint of food production.
# - Processed foods generally have a higher carbon footprint due to the added energy required for processing.
# - Locally produced food has a lower environmental impact due to reduced transport emissions.
# - Higher land use change values are associated with increased biodiversity loss.
# - Water-intensive crops exacerbate water scarcity issues.
# - Sustainable farming methods (e.g., organic, regenerative agriculture) lead to a lower environmental impact.
#
# ## **Analytical Questions**
# 1. Which food products generate the highest and lowest carbon emissions?
# 2. How does the environmental impact of animal-based foods compare with plant-based alternatives?
# 3. What is the relationship between land use change and biodiversity loss?
# 4. Which stage of food production (farming, processing, transportation, packaging, retail) contributes the most to carbon emissions?
# 5. How does the distance food travels during transportation affect its overall emissions?
# 6. Which foods are most responsible for eutrophication (water pollution)?
# 7. What are the most environmentally sustainable food options based on key impact metrics?

# %%
# !pip install matplotlib seaborn
# Out:
# ...
#   Using cached matplotlib-3.10.1-cp313-cp313-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
# Using cached matplotlib-3.10.1-cp313-cp313-win_amd64.whl (8.1 MB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...

# %%
# Data manipulation and analysis
import pandas as pd
import numpy as np

# Data visualization
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.impute import SimpleImputer

# %%
# Load the dataset
data = pd.read_csv("C:\\Users\\LENOVO\\Desktop\\Azubi Africa TMP\\Environment_Impact_of_Food_Production_Analysis\\Notebook\\Data\\Food_Production.csv")
data
# Out:
#            Food product  Land use change  Animal Feed  Farm  Processing  \
# 0   Wheat & Rye (Bread)              0.1          0.0   0.8         0.2
# 1          Maize (Meal)              0.3          0.0   0.5         0.1
# 2         Barley (Beer)              0.0          0.0   0.2         0.1
# 3               Oatmeal              0.0          0.0   1.4         0.0
# 4                  Rice              0.0          0.0   3.6         0.1
# 5              Potatoes              0.0          0.0   0.2         0.0
# 6               Cassava              0.6          0.0   0.2         0.0
# 7            Cane Sugar              1.2          0.0   0.5         0.0
# 8            Beet Sugar              0.0          0.0   0.5         0.2
# 9          Other Pulses              0.0          0.0   1.1         0.0
# 10                 Peas              0.0          0.0   0.7         0.0
# 11                 Nuts             -2.1          0.0   2.1         0.0
# ...

# %%
# Display basic info about the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 23 columns):
#  #   Column                                                                   Non-Null Count  Dtype
# ---  ------                                                                   --------------  -----
#  0   Food product                                                             43 non-null     object
#  1   Land use change                                                          43 non-null     float64
#  2   Animal Feed                                                              43 non-null     float64
#  3   Farm                                                                     43 non-null     float64
#  4   Processing                                                               43 non-null     float64
#  5   Transport                                                                43 non-null     float64
# ...

# %%
# Check for missing values
print("Missing values per column:")
print(data.isnull().sum())
# Out:
# Missing values per column:
# Food product                                                                0
# Land use change                                                             0
# Animal Feed                                                                 0
# Farm                                                                        0
# Processing                                                                  0
# Transport                                                                   0
# Packging                                                                    0
# Retail                                                                      0
# Total_emissions                                                             0
# Eutrophying emissions per 1000kcal (gPO₄eq per 1000kcal)                   10
# Eutrophying emissions per kilogram (gPO₄eq per kilogram)                    5
# Eutrophying emissions per 100g protein (gPO₄eq per 100 grams protein)      16
# ...

# %%
# filling missing values using the mean
numeric_columns = data.select_dtypes(include=[np.number]).columns
imputer = SimpleImputer(strategy='mean')
data[numeric_columns] = imputer.fit_transform(data[numeric_columns])

# %%
# Check for any remaining missing values
print(data.isnull().sum())
# Out:
# Food product                                                               0
# Land use change                                                            0
# Animal Feed                                                                0
# Farm                                                                       0
# Processing                                                                 0
# Transport                                                                  0
# Packging                                                                   0
# Retail                                                                     0
# Total_emissions                                                            0
# Eutrophying emissions per 1000kcal (gPO₄eq per 1000kcal)                   0
# Eutrophying emissions per kilogram (gPO₄eq per kilogram)                   0
# Eutrophying emissions per 100g protein (gPO₄eq per 100 grams protein)      0
# ...

# %%
# Verify the shape of the dataframe
print(f"Shape of the dataframe: {data.shape}")
# Out:
# Shape of the dataframe: (43, 23)

# %%
#Summary Statistics
data.describe()
# Out:
#        Land use change  Animal Feed       Farm  Processing  Transport  \
# count        43.000000    43.000000  43.000000   43.000000  43.000000
# mean          1.260465     0.453488   3.469767    0.253488   0.195349
# std           3.357730     0.919200   7.083264    0.372475   0.158795
# min          -2.100000     0.000000   0.100000    0.000000   0.000000
# 25%           0.000000     0.000000   0.350000    0.000000   0.100000
# 50%           0.200000     0.000000   0.800000    0.100000   0.100000
# 75%           0.800000     0.000000   2.200000    0.300000   0.200000
# max          16.300000     2.900000  39.400000    1.300000   0.800000
#
#         Packging     Retail  Total_emissions  \
# count  43.000000  43.000000        43.000000
# mean    0.269767   0.069767         5.972093
# std     0.342633   0.110270        10.501753
# min     0.000000   0.000000         0.200000
# 25%     0.100000   0.000000         0.850000
# 50%     0.100000   0.000000         1.600000
# ...

# %%
# Get the list of all column names in the DataFrame
columns = data.columns
 
# Print details of unique values for each column in the DataFrame
for column in columns:
    print(f'{column}')  
    print(f'There are {data[column].unique().size} unique values')  
    print(f'{data[column].unique()}')  
    print('_' * 80)
# Out:
# Food product
# There are 43 unique values
# ['Wheat & Rye (Bread)' 'Maize (Meal)' 'Barley (Beer)' 'Oatmeal' 'Rice'
#  'Potatoes' 'Cassava' 'Cane Sugar' 'Beet Sugar' 'Other Pulses' 'Peas'
#  'Nuts' 'Groundnuts' 'Soymilk' 'Tofu' 'Soybean Oil' 'Palm Oil'
#  'Sunflower Oil' 'Rapeseed Oil' 'Olive Oil' 'Tomatoes' 'Onions & Leeks'
#  'Root Vegetables' 'Brassicas' 'Other Vegetables' 'Citrus Fruit' 'Bananas'
#  'Apples' 'Berries & Grapes' 'Wine' 'Other Fruit' 'Coffee'
#  'Dark Chocolate' 'Beef (beef herd)' 'Beef (dairy herd)' 'Lamb & Mutton'
#  'Pig Meat' 'Poultry Meat' 'Milk' 'Cheese' 'Eggs' 'Fish (farmed)'
#  'Shrimps (farmed)']
# ________________________________________________________________________________
# Land use change
# There are 21 unique values
# [ 0.1  0.3  0.   0.6  1.2 -2.1  0.4  0.2  1.   3.1 -0.4 -0.1  3.7 14.3
#  16.3  0.9  0.5  1.5  2.5  4.5  0.7]
# ________________________________________________________________________________
# Animal Feed
# There are 10 unique values
# ...

# %%
# Start exploring relationships between variables
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Land use change', y='Total_emissions', data=data)
plt.title('Land Use Change vs Total Emissions')
plt.xlabel('Land Use Change')
plt.ylabel('Total Emissions')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Total_Emissions', y='Food product', data=data, palette='viridis')
plt.xlabel("Total Carbon Emissions (kg CO2-equivalents per kg product)")
plt.ylabel("Food Product")
plt.title("Food Products and Their Carbon Emissions")
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_14812\1917789355.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Total_Emissions', y='Food product', data=data, palette='viridis')
